# %% [markdown]
# <a href="https://colab.research.google.com/github/21700185-kimtaehong/Int_AI_sample/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('data_set_train.xlsx')

# %%
df.shape
df.columns
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   aptnm(아파트 이름)              17400 non-null  object
#  1   yyyyqrt(거래년도 분기별)          17400 non-null  object
#  2   price(가격)                  17400 non-null  int64
#  3   con_year(건축년도)             17400 non-null  int64
#  4   dong(동)                    17400 non-null  object
#  5   area(면적)                   17400 non-null  float64
#  6   floor(층수)                  17400 non-null  int64
#  7   Latitude(위도)               17400 non-null  float64
#  8   Longtitude(경도)             17400 non-null  float64
#  9   gdp                        17400 non-null  int64
#  10  e_grwth(경제성장률)             17400 non-null  float64
#  11  Seoul_l.rate(지가상승률)        17400 non-null  float64
#  12  house_rate(담보대출금리)         17400 non-null  float64
#  13  dis_park(국립 공원과의 거리)       17400 non-null  float64
#  14  dis_highschool(고등학교와의 거리)  17400 non-null  float64
#  15  dis_reconst(재개발 지역과의 거리)   17400 non-null  float64
#  16  dis_univ(대학과의 거리)          17400 non-null  float64
#  17  dis_hospital(종합 병원과의 거리)   17400 non-null  float64
#  18  dis_museum(국립 박물관과의 거리)    17400 non-null  float64
#  19  dis_subway(지하철역과의 거리)      17400 non-null  float64
#  20  brand_r(유명 아파트 브랜드순)       17400 non-null  int64
#  21  n_home(세대수)                17400 non-null  int64
#  22  n_dong(동수)                 17400 non-null  int64
#  23  parking_per(세대별 주차장수)      17400 non-null  object
#  24  Heater(난방 시스템)             17400 non-null  object
#  25  Yongpae(용적률)               16137 non-null  float64
#  26  Gunpae(건폐율)                15771 non-null  float64
#  27  Highest(최고층)               17400 non-null  int64
#  28  Lowest(최저층)                17400 non-null  int64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 3.8+ MB

# %%
df[df['Yongpae(용적률)'].isnull()].head()
df['Yongpae(용적률)']=df['Yongpae(용적률)'].replace(np.nan,df['Yongpae(용적률)'].mean())

# %%
df['dong(동)'].value_counts()
data1=df[['yyyyqrt(거래년도 분기별)','price(가격)','dong(동)']]
data1.head() # 원하는 column만 가져와 data1에 저장
# Out:
#   yyyyqrt(거래년도 분기별)  price(가격) dong(동)
# 0            2006Q1       9000     역삼동
# 1            2006Q1       9000     역삼동
# 2            2006Q1      73000     개포동
# 3            2006Q1      70000     개포동
# 4            2006Q1      40000     개포동

# %%
data2=data1.copy()
data2.columns=['yearqrt', 'price', 'dong'] #Column 이름 변경

# %%
data_gaepo=data2[data2['dong'] == '개포동']
data_gaepo.head()
# Out:
#   yearqrt  price dong
# 2  2006Q1  73000  개포동
# 3  2006Q1  70000  개포동
# 4  2006Q1  40000  개포동
# 5  2006Q1  56000  개포동
# 6  2006Q1  40500  개포동

# %%
data_gaepo_time=data_gaepo.groupby('yearqrt').mean()
data_gaepo_time
# Out:
# <ipython-input-18-e86269a3403c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_gaepo_time=data_gaepo.groupby('yearqrt').mean()
#                  price
# yearqrt
# 2006Q1    66954.968288
# 2006Q2    69240.408163
# 2006Q3    71064.128440
# 2006Q4    86538.140704
# 2007Q1    79064.285714
# 2007Q2    79900.581395
# 2007Q3    83373.809524
# 2007Q4    79498.275862
# 2008Q1    85955.714286
# 2008Q2    84108.695652
# 2008Q3    77840.000000
# 2008Q4    64602.264706
# 2009Q1    70429.411765
# 2009Q2    83072.031250
# 2009Q3    89909.210526
# 2009Q4    86573.170732
# 2010Q1    88340.909091
# 2010Q2    76193.103448
# 2010Q3    77617.272727
# 2010Q4    79470.494253
# 2011Q1    76050.000000
# 2011Q2    73585.000000
# 2011Q3    73628.409091
# 2011Q4    71094.886364
# 2012Q1    68746.511628
# 2012Q2    64697.014925
# 2012Q3    64296.551724
# 2012Q4    64600.211268
# 2013Q1    65950.000000
# 2013Q2    67389.247312
# 2013Q3    67594.736842
# 2013Q4    68692.537313
# 2014Q1    68837.304348
# 2014Q2    70341.666667
# 2014Q3    72968.292683
# 2014Q4    72984.390244
# 2015Q1    73108.955224
# 2015Q2    77851.844262
# 2015Q3    79815.286624
# 2015Q4    84544.776119
# 2016Q1    82115.326633
# 2016Q2    95733.827751
# 2016Q3   105965.083799
# 2016Q4    98518.253968
# 2017Q1   102040.691824
# 2017Q2   108916.506410
# 2017Q3   121469.615385

# %%
plt.figure(figsize=(60,30))
plt.plot(data_gaepo_time['price'])
