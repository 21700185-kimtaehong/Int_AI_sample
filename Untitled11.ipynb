# %% [markdown]
# <a href="https://colab.research.google.com/github/21700185-kimtaehong/Int_AI_sample/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 32
input_img = Input(shape=(784,)) #784 = 28x28
encoded = Dense(encoding_dim, activation='relu')(input_img)
encoder = Model(input_img, encoded)

# %%
#need to re-define input layer for decoder input
encoded_input = Input(shape=(encoding_dim,))
decoded = Dense(784, activation='sigmoid')(encoded_input)
decoder = Model(encoded_input, decoded)

outputs = decoder(encoder(input_img))
autoencoder = Model(input_img, outputs)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# float32 / 255 : 값을 0~1로 만들기
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
autoencoder.fit(x_train, x_train,epochs=50,batch_size=256,shuffle=True,validation_data=(x_test, x_test))

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 14s 9ms/step - loss: 0.2756 - val_loss: 0.1849
# Epoch 2/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1679 - val_loss: 0.1514
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1432 - val_loss: 0.1332
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1283 - val_loss: 0.1210
# Epoch 5/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1184 - val_loss: 0.1129
# Epoch 6/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1116 - val_loss: 0.1076
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1067 - val_loss: 0.1032
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1029 - val_loss: 0.0999
# Epoch 9/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1000 - val_loss: 0.0975
# Epoch 10/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0979 - val_loss: 0.0958
# Epoch 11/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0965 - val_loss: 0.0946
# Epoch 12/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0956 - val_loss: 0.0939
# Epoch 13/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0950 - val_loss: 0.0936
# Epoch 14/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0946 - val_loss: 0.0932
# Epoch 15/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0943 - val_loss: 0.0929
# Epoch 16/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0941 - val_loss: 0.0928
# Epoch 17/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0939 - val_loss: 0.0927
# Epoch 18/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 19/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 20/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 21/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 22/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 23/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 24/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 25/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 26/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 27/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 28/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 29/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 30/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 31/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 33/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 34/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 35/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 37/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 38/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 39/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 40/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 41/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 43/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 45/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 46/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 47/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 48/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 49/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 50/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0926 - val_loss: 0.0915
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt

def display(array1, array2):
    """
    Displays ten random images from each one of the supplied arrays.
    """

    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
import tensorflow as tf

from tensorflow.python.keras import layers
# from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.models import Model

def preprocess(array):
    """
    Normalizes the supplied array and reshapes it into the appropriate format.
    """

    array = array.astype("float32") / 255.0
    array = np.reshape(array, (len(array), 28, 28, 1))
    return array

# %%
from keras.datasets import mnist
import numpy as np

(train_data, _), (test_data, _) = mnist.load_data()
# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# %%
input = layers.Input(shape=(28, 28, 1))
# Encoder
x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(input)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
# Decoder
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2D(1, (3, 3), activation="sigmoid", padding="same")(x)
# Autoencoder
autoencoder = Model(input, x)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")
# autoencoder.summary()

# %%
autoencoder.fit(
  x=train_data,
  y=train_data,
  epochs=50,
  batch_size=128,
  shuffle=True,
  validation_data=(test_data, test_data),
)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 10s 8ms/step - loss: 0.1364 - val_loss: 0.0728
# Epoch 2/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0713 - val_loss: 0.0693
# Epoch 3/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0691 - val_loss: 0.0679
# Epoch 4/50
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0680 - val_loss: 0.0671
# Epoch 5/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0673 - val_loss: 0.0666
# Epoch 6/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0667 - val_loss: 0.0660
# Epoch 7/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0663 - val_loss: 0.0658
# Epoch 8/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0660 - val_loss: 0.0654
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0657 - val_loss: 0.0651
# Epoch 10/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0654 - val_loss: 0.0650
# Epoch 11/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0652 - val_loss: 0.0647
# Epoch 12/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0650 - val_loss: 0.0646
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0648 - val_loss: 0.0644
# Epoch 14/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0647 - val_loss: 0.0642
# Epoch 15/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0645 - val_loss: 0.0640
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0644 - val_loss: 0.0639
# Epoch 17/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0643 - val_loss: 0.0639
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0642 - val_loss: 0.0637
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0641 - val_loss: 0.0636
# Epoch 20/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0640 - val_loss: 0.0636
# Epoch 21/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0639 - val_loss: 0.0635
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0638 - val_loss: 0.0634
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0637 - val_loss: 0.0633
# Epoch 24/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0637 - val_loss: 0.0633
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0636 - val_loss: 0.0633
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0635 - val_loss: 0.0632
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0635 - val_loss: 0.0632
# Epoch 28/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0634 - val_loss: 0.0630
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0634 - val_loss: 0.0630
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0633 - val_loss: 0.0629
# Epoch 31/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0633 - val_loss: 0.0630
# Epoch 32/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0632 - val_loss: 0.0630
# Epoch 33/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0632 - val_loss: 0.0629
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0632 - val_loss: 0.0628
# Epoch 35/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0631 - val_loss: 0.0628
# Epoch 36/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0631 - val_loss: 0.0627
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0630 - val_loss: 0.0627
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0630 - val_loss: 0.0627
# Epoch 39/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0630 - val_loss: 0.0626
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0629 - val_loss: 0.0626
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0629 - val_loss: 0.0626
# Epoch 42/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0629 - val_loss: 0.0625
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0628 - val_loss: 0.0625
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0628 - val_loss: 0.0625
# Epoch 45/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0628 - val_loss: 0.0625
# Epoch 46/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0628 - val_loss: 0.0624
# Epoch 47/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0624
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0624
# Epoch 49/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0627 - val_loss: 0.0625
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0624

# %%
predictions = autoencoder.predict(test_data)
display(test_data, predictions)

# %%
def noise(array):
    """
    Adds random noise to each image in the supplied array.
    """

    noise_factor = 0.4
    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )

    return np.clip(noisy_array, 0.0, 1.0)

# %%
(train_data, _), (test_data, _) = mnist.load_data()

# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# Create a copy of the data with added noise
noisy_train_data = noise(train_data)
noisy_test_data = noise(test_data)

# Display the train data and a version of it with added noise
display(train_data, noisy_train_data)

# %%
temp1_predictions = autoencoder.predict(noisy_test_data)
display(noisy_test_data, temp1_predictions)

# %%
temp2_predictions = autoencoder.predict(noisy_train_data)
display(noisy_train_data, temp2_predictions)
