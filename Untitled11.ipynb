# %% [markdown]
# <a href="https://colab.research.google.com/github/21700185-kimtaehong/Int_AI_sample/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 32
input_img = Input(shape=(784,)) #784 = 28x28
encoded = Dense(encoding_dim, activation='relu')(input_img)
encoder = Model(input_img, encoded)

# %%
#need to re-define input layer for decoder input
encoded_input = Input(shape=(encoding_dim,))
decoded = Dense(784, activation='sigmoid')(encoded_input)
decoder = Model(encoded_input, decoded)

outputs = decoder(encoder(input_img))
autoencoder = Model(input_img, outputs)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# float32 / 255 : 값을 0~1로 만들기
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
autoencoder.fit(x_train, x_train,epochs=50,batch_size=256,shuffle=True,validation_data=(x_test, x_test))

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 4ms/step - loss: 0.2789 - val_loss: 0.1921
# Epoch 2/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1724 - val_loss: 0.1544
# Epoch 3/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1446 - val_loss: 0.1337
# Epoch 4/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1285 - val_loss: 0.1214
# Epoch 5/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1184 - val_loss: 0.1132
# Epoch 6/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1117 - val_loss: 0.1079
# Epoch 7/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1069 - val_loss: 0.1037
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1032 - val_loss: 0.1003
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1004 - val_loss: 0.0979
# Epoch 10/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0983 - val_loss: 0.0961
# Epoch 11/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0969 - val_loss: 0.0950
# Epoch 12/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0959 - val_loss: 0.0944
# Epoch 13/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0953 - val_loss: 0.0938
# Epoch 14/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0948 - val_loss: 0.0933
# Epoch 15/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0945 - val_loss: 0.0930
# Epoch 16/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0942 - val_loss: 0.0928
# Epoch 17/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 18/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0939 - val_loss: 0.0925
# Epoch 19/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 20/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0936 - val_loss: 0.0923
# Epoch 21/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 22/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 23/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0933 - val_loss: 0.0922
# Epoch 24/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 25/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 26/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 27/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 28/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 29/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 30/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 33/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 35/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 37/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 38/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 39/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 40/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 41/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 42/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 43/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 45/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 46/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 47/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 48/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 49/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 50/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt

def display(array1, array2):
    """
    Displays ten random images from each one of the supplied arrays.
    """

    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
import tensorflow as tf

from tensorflow.python.keras import layers
# from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.models import Model

def preprocess(array):
    """
    Normalizes the supplied array and reshapes it into the appropriate format.
    """

    array = array.astype("float32") / 255.0
    array = np.reshape(array, (len(array), 28, 28, 1))
    return array

# %%
from keras.datasets import mnist
import numpy as np

(train_data, _), (test_data, _) = mnist.load_data()
# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# %%
input = layers.Input(shape=(28, 28, 1))
# Encoder
x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(input)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
# Decoder
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2D(1, (3, 3), activation="sigmoid", padding="same")(x)
# Autoencoder
autoencoder = Model(input, x)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")
# autoencoder.summary()

# %%
autoencoder.fit(
  x=train_data,
  y=train_data,
  epochs=50,
  batch_size=128,
  shuffle=True,
  validation_data=(test_data, test_data),
)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1297 - val_loss: 0.0732
# Epoch 2/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0715 - val_loss: 0.0694
# Epoch 3/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0691 - val_loss: 0.0678
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0679 - val_loss: 0.0669
# Epoch 5/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0671 - val_loss: 0.0663
# Epoch 6/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0665 - val_loss: 0.0658
# Epoch 7/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0660 - val_loss: 0.0654
# Epoch 8/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0656 - val_loss: 0.0652
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0653 - val_loss: 0.0647
# Epoch 10/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0650 - val_loss: 0.0645
# Epoch 11/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0648 - val_loss: 0.0643
# Epoch 12/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0646 - val_loss: 0.0641
# Epoch 13/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0644 - val_loss: 0.0640
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0642 - val_loss: 0.0637
# Epoch 15/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0641 - val_loss: 0.0636
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0640 - val_loss: 0.0636
# Epoch 17/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0638 - val_loss: 0.0634
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0637 - val_loss: 0.0634
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0636 - val_loss: 0.0632
# Epoch 20/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0635 - val_loss: 0.0632
# Epoch 21/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0635 - val_loss: 0.0631
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0634 - val_loss: 0.0631
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0633 - val_loss: 0.0630
# Epoch 24/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0633 - val_loss: 0.0629
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0632 - val_loss: 0.0629
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0631 - val_loss: 0.0627
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0631 - val_loss: 0.0628
# Epoch 28/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0630 - val_loss: 0.0627
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0630 - val_loss: 0.0626
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0630 - val_loss: 0.0626
# Epoch 31/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0629 - val_loss: 0.0626
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0629 - val_loss: 0.0625
# Epoch 33/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0628 - val_loss: 0.0625
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0628 - val_loss: 0.0625
# Epoch 35/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0628 - val_loss: 0.0624
# Epoch 36/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0624
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0624
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0627 - val_loss: 0.0623
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0626 - val_loss: 0.0623
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0626 - val_loss: 0.0623
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0626 - val_loss: 0.0624
# Epoch 42/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0626 - val_loss: 0.0623
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0625 - val_loss: 0.0623
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0625 - val_loss: 0.0622
# Epoch 45/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0625 - val_loss: 0.0622
# Epoch 46/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0625 - val_loss: 0.0621
# Epoch 47/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0625 - val_loss: 0.0622
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0624 - val_loss: 0.0622
# Epoch 49/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0624 - val_loss: 0.0621
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0624 - val_loss: 0.0620

# %%
predictions = autoencoder.predict(test_data)
display(test_data, predictions)

# %%
def noise(array):
    """
    Adds random noise to each image in the supplied array.
    """

    noise_factor = 0.4
    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )

    return np.clip(noisy_array, 0.0, 1.0)

# %%
(train_data, _), (test_data, _) = mnist.load_data()

# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# Create a copy of the data with added noise
noisy_train_data = noise(train_data)
noisy_test_data = noise(test_data)

# Display the train data and a version of it with added noise
display(train_data, noisy_train_data)

# %%
temp1_predictions = autoencoder.predict(noisy_test_data)
display(test_data, temp1_predictions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-c7d6f8c91010> in <cell line: 2>()
#       1 temp1_predictions = autoencoder.predict(noisy_test_data)
# ----> 2 display(train_data, temp1_predictions)
#
# <ipython-input-74-346ef3e2143e> in display(array1, array2)
#      10     indices = np.random.randint(len(array1), size=n)
#      11     images1 = array1[indices, :]
# ---> 12     images2 = array2[indices, :]
#      13
#      14     plt.figure(figsize=(20, 4))
#
# IndexError: index 49076 is out of bounds for axis 0 with size 10000

# %%
temp2_predictions = autoencoder.predict(noisy_train_data)
display(noisy_train_data, temp2_predictions)
